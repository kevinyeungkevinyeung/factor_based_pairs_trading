# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
from factor_data import FactorData
from price_data import PriceData
from factor_model import FactorModel
from pca import PCA
from clustering import Cluster
from find_pairs import PairsTrade
from allocator import Allocator
from pma import PMA


from matplotlib import style
import matplotlib.pyplot as plt
# plt.style.use('bmh')

from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
# %%time

def generate_datelist(start_date, end_date, freq="w"):
    if freq=="w":
        date_list = pd.date_range(start=start_date, end=end_date, 
                             freq='W-MON').strftime('%Y-%m-%d').tolist()
        
    else:
        date_list =[str(d)+"-01" for d in list(pd.period_range(start=start_date, end=end_date, freq='M'))]
    
    return date_list



date_list = generate_datelist("2020-12-01","2022-12-01",freq="m")
pma = PMA(1000000,date_list[0],allocation_per_trade=50000) # create a pma to record trades

sample_length = 5 # the length of the sample period
display = False # to show the pairs trade graphs


for da in date_list:

    
    print(F"Running ..... {da}")
    
    dt = datetime.strptime(da, '%Y-%m-%d')
    start = str(dt - relativedelta(years=sample_length))[:10] # get start from for the sample period data
    
    lookback_start = str(dt - relativedelta(months=1))[:10]
    
    # get price data for the sample period
    sample_data = PriceData(["all"], start=start, end=da, ticker_ref_date=da, refresh=False)
    
    # get price data for the out of sample period
    lookback_data = PriceData(["all"], start=lookback_start, end=da, ticker_ref_date=da, refresh=False)
    
    # get the factor data for the sample period
    factors = FactorData("all", frequency="m", start=start, end=da)
    
    # run the ts regression to get factor betas
    _factor_model = FactorModel(
                                sample_data.asset_return, 
                                factors.factor_data,
                                ts_pvalues_threshold=0.1,
                                factor_hard_cap=25,
                                coff_std_limit=5
    )

    # apply PCA to the data
    _pca = PCA(_factor_model.clustering_coefficients,cum_explain_threshold=0.85)

    # clsuter the data
    cluster = Cluster(
                      _pca.pca,
                      method="DBCSAN",
                      number_of_cluster=None,
                      cluster_cap=8,
                      cluster_floor=None,
                      graph=True
                    )

    # find pairs
    pairs_trade = PairsTrade(
                             _factor_model,
                             cluster, 
                             sample_data, 
                             lookback_data,
                             allocation_date=da,
                             entry_zscore=3,
                             stop_loss_zscore=5,
                             test_percentile=0.5,
                             display=display
                            )


    
    # put the trades into the allocator
    allocator = Allocator(pairs_trade.pairs,trade_date=da)
    
    # add the trades into the pma
    pma.add_to_pma(allocator.orders,allocator.info,da)
    
    
    # run pma to calculate aum
    pma.run_pma(da)
    
    
    print("""
    
---------------------------------------------------------------

""")
# Out:
# Running ..... 2020-12-01
#     609 of ticker.
# EPS = 0.3325, # of Cluster = 8 and # of Ticker 311
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# --------- Runing Cluster 7.0 ---------------
# --------- Runing Cluster 8.0 ---------------
# --------- Runing Cluster 9.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Added 18 Trades, Number of Allocation Increased from 0 to 18
#                   Cash Amount went from 1000000 to 728880.71
#                   With Exchange Fee of 2343.36
#
# Date: 2020-12-01 -- AUM: 995611.84
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-01-01
#     604 of ticker.
# EPS = 0.31, # of Cluster = 8 and # of Ticker 294
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 18 Trades, Number of Allocation Reduced from 18 to 0
#                   Cash Amount went from 728880.71 to 980730.36
#                   With Exchange Fee of 2292.52
#
#
# Sent Trade to Exchange....
#
#
#                   Added 14 Trades, Number of Allocation Increased from 0 to 14
#                   Cash Amount went from 980730.36 to 743398.39
#                   With Exchange Fee of 1333.85
#
# Date: 2021-01-01 -- AUM: 983030.77
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-02-01
#     620 of ticker.
# EPS = 0.255, # of Cluster = 8 and # of Ticker 230
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 14 Trades, Number of Allocation Reduced from 14 to 0
#                   Cash Amount went from 743398.39 to 976858.32
#                   With Exchange Fee of 1326.06
#
#
# Sent Trade to Exchange....
#
#
#                   Added 8 Trades, Number of Allocation Increased from 0 to 8
#                   Cash Amount went from 976858.32 to 916690.07
#                   With Exchange Fee of 1934.36
#
# Date: 2021-02-01 -- AUM: 968843.03
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-03-01
#     621 of ticker.
# EPS = 0.3425, # of Cluster = 8 and # of Ticker 300
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 6 Trades, Number of Allocation Reduced from 8 to 2
#                   Cash Amount went from 916690.07 to 856401.79
#                   With Exchange Fee of 1466.82
#
#
# Sent Trade to Exchange....
#
#
#                   Added 12 Trades, Number of Allocation Increased from 2 to 14
#                   Cash Amount went from 856401.79 to 284122.48
#                   With Exchange Fee of 3011.72
#
# Date: 2021-03-01 -- AUM: 942497.06
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-04-01
#     627 of ticker.
# EPS = 0.1475, # of Cluster = 8 and # of Ticker 133
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# --------- Runing Cluster 7.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 14 Trades, Number of Allocation Reduced from 14 to 0
#                   Cash Amount went from 284122.48 to 1014828.62
#                   With Exchange Fee of 3865.14
#
#
# Date: 2021-04-01 -- AUM: 1017487.62
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-05-01
#     627 of ticker.
# EPS = 0.46499999999999997, # of Cluster = 8 and # of Ticker 452
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Added 38 Trades, Number of Allocation Increased from 0 to 38
#                   Cash Amount went from 1014828.62 to 1064836.08
#                   With Exchange Fee of 3193.06
#
# Date: 2021-05-01 -- AUM: 1030015.37
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-06-01
#     628 of ticker.
# EPS = 0.585, # of Cluster = 8 and # of Ticker 502
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 36 Trades, Number of Allocation Reduced from 38 to 2
#                   Cash Amount went from 1064836.08 to 1008918.05
#                   With Exchange Fee of 3092.54
#
#
# Sent Trade to Exchange....
#
#
#                   Added 16 Trades, Number of Allocation Increased from 2 to 18
#                   Cash Amount went from 1008918.05 to 719848.01
#                   With Exchange Fee of 3928.57
#
# Date: 2021-06-01 -- AUM: 993296.85
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-07-01
#     629 of ticker.
# EPS = 0.4425, # of Cluster = 8 and # of Ticker 439
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 18 Trades, Number of Allocation Reduced from 18 to 0
#                   Cash Amount went from 719848.01 to 1033261.63
#                   With Exchange Fee of 4291.79
#
#
# Sent Trade to Exchange....
#
#
#                   Added 28 Trades, Number of Allocation Increased from 0 to 28
#                   Cash Amount went from 1033261.63 to 885169.94
#                   With Exchange Fee of 3123.14
#
# Date: 2021-07-01 -- AUM: 1041077.63
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-08-01
#     634 of ticker.
# EPS = 0.5725, # of Cluster = 8 and # of Ticker 495
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 28 Trades, Number of Allocation Reduced from 28 to 0
#                   Cash Amount went from 885169.94 to 1029767.81
#                   With Exchange Fee of 3219.89
#
#
# Sent Trade to Exchange....
#
#
#                   Added 18 Trades, Number of Allocation Increased from 0 to 18
#                   Cash Amount went from 1029767.81 to 737751.37
#                   With Exchange Fee of 3143.3
#
# Date: 2021-08-01 -- AUM: 1022488.37
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-09-01
#     634 of ticker.
# EPS = 0.43, # of Cluster = 8 and # of Ticker 432
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# --------- Runing Cluster 7.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 18 Trades, Number of Allocation Reduced from 18 to 0
#                   Cash Amount went from 737751.37 to 1039433.42
#                   With Exchange Fee of 3241.26
#
#
# Sent Trade to Exchange....
#
#
#                   Added 14 Trades, Number of Allocation Increased from 0 to 14
#                   Cash Amount went from 1039433.42 to 484073.62
#                   With Exchange Fee of 3508.13
#
# Date: 2021-09-01 -- AUM: 1032031.58
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-10-01
#     627 of ticker.
# EPS = 0.24, # of Cluster = 8 and # of Ticker 248
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# --------- Runing Cluster 7.0 ---------------
# --------- Runing Cluster 8.0 ---------------
# --------- Runing Cluster 9.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 14 Trades, Number of Allocation Reduced from 14 to 0
#                   Cash Amount went from 484073.62 to 998777.53
#                   With Exchange Fee of 3289.13
#
#
# Sent Trade to Exchange....
#
#
#                   Added 2 Trades, Number of Allocation Increased from 0 to 2
#                   Cash Amount went from 998777.53 to 1056084.73
#                   With Exchange Fee of 498.35
#
# Date: 2021-10-01 -- AUM: 1004300.16
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-11-01
#     621 of ticker.
# EPS = 0.45, # of Cluster = 8 and # of Ticker 418
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 2 Trades, Number of Allocation Reduced from 2 to 0
#                   Cash Amount went from 1056084.73 to 996697.92
#                   With Exchange Fee of 521.61
#
#
# Sent Trade to Exchange....
#
#
#                   Added 16 Trades, Number of Allocation Increased from 0 to 16
#                   Cash Amount went from 996697.92 to 734603.34
#                   With Exchange Fee of 3532.72
#
# Date: 2021-11-01 -- AUM: 994370.98
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2021-12-01
#     627 of ticker.
# EPS = 0.55, # of Cluster = 8 and # of Ticker 485
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 16 Trades, Number of Allocation Reduced from 16 to 0
#                   Cash Amount went from 734603.34 to 971364.65
#                   With Exchange Fee of 3489.38
#
#
# Sent Trade to Exchange....
#
#
#                   Added 24 Trades, Number of Allocation Increased from 0 to 24
#                   Cash Amount went from 971364.65 to 521844.73
#                   With Exchange Fee of 4099.41
#
# Date: 2021-12-01 -- AUM: 986541.82
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-01-01
#     626 of ticker.
# EPS = 0.535, # of Cluster = 8 and # of Ticker 472
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 22 Trades, Number of Allocation Reduced from 24 to 2
#                   Cash Amount went from 521844.73 to 911985.9
#                   With Exchange Fee of 3890.29
#
#
# Sent Trade to Exchange....
#
#
#                   Added 12 Trades, Number of Allocation Increased from 2 to 14
#                   Cash Amount went from 911985.9 to 487561.77
#                   With Exchange Fee of 2254.69
#
# Date: 2022-01-01 -- AUM: 993464.76
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-02-01
#     633 of ticker.
# EPS = 0.415, # of Cluster = 8 and # of Ticker 405
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 14 Trades, Number of Allocation Reduced from 14 to 0
#                   Cash Amount went from 487561.77 to 944755.59
#                   With Exchange Fee of 2433.45
#
#
# Sent Trade to Exchange....
#
#
#                   Added 2 Trades, Number of Allocation Increased from 0 to 2
#                   Cash Amount went from 944755.59 to 886754.89
#                   With Exchange Fee of 500.56
#
# Date: 2022-02-01 -- AUM: 948057.41
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-03-01
#     631 of ticker.
# EPS = 0.2275, # of Cluster = 8 and # of Ticker 184
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# --------- Runing Cluster 7.0 ---------------
# --------- Runing Cluster 8.0 ---------------
# --------- Runing Cluster 9.0 ---------------
# --------- Runing Cluster 10.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 2 Trades, Number of Allocation Reduced from 2 to 0
#                   Cash Amount went from 886754.89 to 949575.4
#                   With Exchange Fee of 533.61
#
#
# Sent Trade to Exchange....
#
#
#                   Added 10 Trades, Number of Allocation Increased from 0 to 10
#                   Cash Amount went from 949575.4 to 832434.18
#                   With Exchange Fee of 2500.31
#
# Date: 2022-03-01 -- AUM: 967553.98
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-04-01
#     627 of ticker.
# EPS = 0.48, # of Cluster = 8 and # of Ticker 493
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 10 Trades, Number of Allocation Reduced from 10 to 0
#                   Cash Amount went from 832434.18 to 953825.28
#                   With Exchange Fee of 2687.44
#
#
# Sent Trade to Exchange....
#
#
#                   Added 18 Trades, Number of Allocation Increased from 0 to 18
#                   Cash Amount went from 953825.28 to 584272.46
#                   With Exchange Fee of 3342.94
#
# Date: 2022-04-01 -- AUM: 952149.16
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-05-01
#     622 of ticker.
# EPS = 0.375, # of Cluster = 8 and # of Ticker 386
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 18 Trades, Number of Allocation Reduced from 18 to 0
#                   Cash Amount went from 584272.46 to 928175.68
#                   With Exchange Fee of 3099.29
#
#
# Sent Trade to Exchange....
#
#
#                   Added 8 Trades, Number of Allocation Increased from 0 to 8
#                   Cash Amount went from 928175.68 to 780835.67
#                   With Exchange Fee of 2001.28
#
# Date: 2022-05-01 -- AUM: 933833.73
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-06-01
#     619 of ticker.
# EPS = 0.3975, # of Cluster = 8 and # of Ticker 414
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 8 Trades, Number of Allocation Reduced from 8 to 0
#                   Cash Amount went from 780835.67 to 929166.86
#                   With Exchange Fee of 2078.75
#
#
# Sent Trade to Exchange....
#
#
#                   Added 14 Trades, Number of Allocation Increased from 0 to 14
#                   Cash Amount went from 929166.86 to 367706.91
#                   With Exchange Fee of 3137.23
#
# Date: 2022-06-01 -- AUM: 896544.6
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-07-01
#     625 of ticker.
# EPS = 0.175, # of Cluster = 8 and # of Ticker 123
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 14 Trades, Number of Allocation Reduced from 14 to 0
#                   Cash Amount went from 367706.91 to 861577.43
#                   With Exchange Fee of 2801.42
#
#
# Sent Trade to Exchange....
#
#
#                   Added 2 Trades, Number of Allocation Increased from 0 to 2
#                   Cash Amount went from 861577.43 to 815866.17
#                   With Exchange Fee of 500.96
#
# Date: 2022-07-01 -- AUM: 852299.59
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-08-01
#     628 of ticker.
# EPS = 0.1625, # of Cluster = 8 and # of Ticker 123
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 2 Trades, Number of Allocation Reduced from 2 to 0
#                   Cash Amount went from 815866.17 to 860215.49
#                   With Exchange Fee of 506.69
#
#
# Date: 2022-08-01 -- AUM: 862526.47
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-09-01
#     630 of ticker.
# EPS = 0.2, # of Cluster = 8 and # of Ticker 196
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Date: 2022-09-01 -- AUM: 862409.98
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-10-01
#     632 of ticker.
# EPS = 0.215, # of Cluster = 8 and # of Ticker 211
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Date: 2022-10-01 -- AUM: 862339.1
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-11-01
#     623 of ticker.
# EPS = 0.14, # of Cluster = 8 and # of Ticker 90
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Added 2 Trades, Number of Allocation Increased from 0 to 2
#                   Cash Amount went from 860215.49 to 866152.64
#                   With Exchange Fee of 499.45
#
# Date: 2022-11-01 -- AUM: 861443.22
#
#
# ---------------------------------------------------------------
#
#
# Running ..... 2022-12-01
#     625 of ticker.
# EPS = 0.135, # of Cluster = 8 and # of Ticker 106
# --------- Runing Cluster 0.0 ---------------
# --------- Runing Cluster 1.0 ---------------
# --------- Runing Cluster 2.0 ---------------
# --------- Runing Cluster 3.0 ---------------
# --------- Runing Cluster 4.0 ---------------
# --------- Runing Cluster 5.0 ---------------
# --------- Runing Cluster 6.0 ---------------
# Sent Trade to Exchange....
#
#
#                   Closed 2 Trades, Number of Allocation Reduced from 2 to 0
#                   Cash Amount went from 866152.64 to 852730.06
#                   With Exchange Fee of 522.97
#
#
# Date: 2022-12-01 -- AUM: 855053.21
#
#
# ---------------------------------------------------------------
#
#
# CPU times: user 27min 24s, sys: 25.2 s, total: 27min 49s
# Wall time: 27min 41s

# %%
pma.aum_history.to_csv("backtest/DBSCAN-0.5-historical_aum.csv")
pma.number_of_trade.to_csv("backtest/DBSCAN-0.5-number_of_trade.csv")
pma.total_long_position.to_csv("backtest/DBSCAN-0.5-long.csv")
pma.total_short_position.to_csv("backtest/DBSCAN-0.5-short.csv")
